# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import missingno as msno
import datetime as dt

# %%
url = 'https://raw.githubusercontent.com/PoornimasreJegannathan/Poorni/main/Copper_In_Set.csv'
copin = pd.read_csv(url)
copin.head()
# Out:
# <ipython-input-4-3762ee968426>:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   copin = pd.read_csv(url)
#                                      id   item_date quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949  30153963.0
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065  30349574.0
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262  30211560.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
# 3     32.0    Won         S         59.0       2.30  1317.0
# ...

# %%
# won_sales = copin[copin['status'] == 'Won']
# lost_sales = copin[copin['status'] == 'Lost']

# %%
# plt.hist(won_sales['selling_price'], bins=30, alpha=0.5, label='Won')
# plt.hist(lost_sales['selling_price'], bins=30, alpha=0.5, label='Lost')
# plt.xlabel('Selling Price')
# plt.ylabel('Frequency')
# plt.legend()
# plt.show()

# %%
# plt.figure(figsize=(10, 6))
# sns.histplot(data=won_sales,x='selling_price',hue='status',alpha=0.5, label='Won')
# sns.histplot(data=lost_sales,x='selling_price',hue='status',alpha=0.5, label='Lost',palette={'Lost':'red'})
# plt.xlabel('Selling Price')
# plt.ylabel('Frequency')
# plt.legend()
# plt.show()


# sns.rugplot(data=won_sales,x='selling_price',hue='item type',alpha=0.5, label='S')
# sns.rugplot(data=lost_sales,x='selling_price',hue='item type',alpha=0.5, label='PL',palette={'PL':'red'})
# plt.xlim(1, 1800)
# plt.xlabel('Selling Price')
# plt.ylabel('Frequency')
# plt.legend()
# plt.show()

# %%
# copin1 = copin.copy()
print(type(copin))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#airbnb['host_name'].isnull().sum() --checking missing values
# copin_new=copin['id'].isnull().sum()
# copin_new=copin['item_date'].isnull().sum()
# copin_new=copin['customer'].isnull().sum()
# copin_new=copin['country'].isnull().sum()
# copin_new=copin['status'].isnull().sum()
# copin_new=copin['application'].isnull().sum()
# copin_new=copin['thickness'].isnull().sum()
# copin_new=copin['material_ref'].isnull().sum()
# copin_new=copin['delivery date'].isnull().sum()
copin['selling_price'].isnull().sum()
# Out:
# 1

# %%
copin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181673 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             181671 non-null  object
#  1   item_date      181672 non-null  float64
#  2   quantity tons  181673 non-null  object
#  3   customer       181672 non-null  float64
#  4   country        181645 non-null  float64
#  5   status         181671 non-null  object
#  6   item type      181673 non-null  object
#  7   application    181649 non-null  float64
#  8   thickness      181672 non-null  float64
#  9   width          181673 non-null  float64
#  10  material_ref   103754 non-null  object
#  11  product_ref    181673 non-null  int64
#  12  delivery date  181672 non-null  float64
#  13  selling_price  181672 non-null  float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 19.4+ MB

# %%
# copin.dropna(subset='selling_price', inplace=True) # 1 null
# copin.dropna(subset='id', inplace=True)           # 2 null
# copin.dropna(subset='item_date', inplace=True)    # 1 null
# copin.dropna(subset='customer', inplace=True)     # 1 null
# copin.dropna(subset='status', inplace=True)       # 2 null
# copin.dropna(subset='thickness', inplace=True)    # 1 null
# copin.dropna(subset='delivery date', inplace=True) #  1 null

# %%
copin['selling_price'].isnull().sum()
# Out:
# 0

# %%
copin.groupby('status').selling_price.mean()
# Out:
# status
# Draft                 16.555096
# Lost                 806.727589
# Not lost for AM     5955.585557
# Offerable            951.000000
# Offered             1017.358491
# Revised              855.863548
# To be approved     24916.533898
# Won                  831.418537
# Wonderful           1136.000000
# Name: selling_price, dtype: float64

# %%
print(copin['status'].value_counts())
# Out:
# status
# Won                116007
# Lost                34436
# Not lost for AM     19572
# Revised              4276
# To be approved       4169
# Draft                3140
# Offered                53
# Offerable              10
# Wonderful               1
# Name: count, dtype: int64

# %%
copin.groupby(['status','item type',]).selling_price.mean()

# %%
# copin.loc[(copin['status']=='Lost') & (copin['item type'] == 'Others')& (copin['selling_price'] < 831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Lost') & (copin['item type'] == 'Others')& (copin['selling_price'] > 831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Lost') & (copin['item type'] == 'W')& (copin['selling_price']<831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Lost') & (copin['item type'] == 'W')& (copin['selling_price']>831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Lost') & (copin['item type'] == 'W')& (copin['selling_price']==831), 'item type'] = 'S'

# %%
# copin.loc[(copin['status']=='Not lost for AM') & (copin['item type'] == 'Others')& (copin['selling_price']>831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Not lost for AM') & (copin['item type'] == 'Others')& (copin['selling_price']<831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Not lost for AM') & (copin['item type'] == 'W')& (copin['selling_price']<831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Not lost for AM') & (copin['item type'] == 'W')& (copin['selling_price']>831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Not lost for AM') & (copin['item type'] == 'WI')& (copin['selling_price']<831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Not lost for AM') & (copin['item type'] == 'WI')& (copin['selling_price']>831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Not lost for AM') & (copin['item type'] == 'W')& (copin['selling_price']==831), 'item type'] = 'PL'

# %%
# copin.loc[(copin['status']=='Offerable') & (copin['item type'] == 'W')& (copin['selling_price']>831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Offerable') & (copin['item type'] == 'W')& (copin['selling_price']<831), 'item type'] = 'PL'

# %%
# copin.loc[(copin['status']=='Offered') & (copin['item type'] == 'W')& (copin['selling_price']>831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Offered') & (copin['item type'] == 'W')& (copin['selling_price']<831), 'item type'] = 'PL'

# %%
# copin.loc[(copin['status']=='Revised') & (copin['item type'] == 'Others')& (copin['selling_price']>831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Revised') & (copin['item type'] == 'Others')& (copin['selling_price']<831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Revised') & (copin['item type'] == 'W')& (copin['selling_price']<831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Revised') & (copin['item type'] == 'W')& (copin['selling_price']>831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Revised') & (copin['item type'] == 'WI')& (copin['selling_price']<831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Revised') & (copin['item type'] == 'WI')& (copin['selling_price']>831), 'item type'] = 'S'
copin.loc[(copin['status']=='Revised') & (copin['item type'] == 'W')& (copin['selling_price']==831), 'item type'] = 'PL'

# %%
# copin.loc[(copin['status']=='To be approved') & (copin['item type'] == 'W')& (copin['selling_price']>831), 'item type'] = 'S'
# copin.loc[(copin['status']=='To be approved') & (copin['item type'] == 'W')& (copin['selling_price']<831), 'item type'] = 'PL'
copin.loc[(copin['status']=='To be approved') & (copin['item type'] == 'W')& (copin['selling_price']==831), 'item type'] = 'PL'

# %%
# copin.loc[(copin['status']=='Won') & (copin['item type'] == 'IPL')& (copin['selling_price'] >831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Won') & (copin['item type'] == 'IPL')& (copin['selling_price'] <831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Won') & (copin['item type'] == 'Others')& (copin['selling_price']>831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Won') & (copin['item type'] == 'Others')& (copin['selling_price']<831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Won') & (copin['item type'] == 'Others')& (copin['selling_price']==831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Won') & (copin['item type'] == 'W')& (copin['selling_price']<831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Won') & (copin['item type'] == 'W')& (copin['selling_price']>831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Won') & (copin['item type'] == 'W')& (copin['selling_price']==831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Won') & (copin['item type'] == 'WI')& (copin['selling_price']<831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Won') & (copin['item type'] == 'WI')& (copin['selling_price']>831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Won') & (copin['item type'] == 'WI')& (copin['selling_price']==831), 'item type'] = 'PL'
# copin.loc[(copin['status']=='Won') & (copin['item type'] == 'SLAWR')& (copin['selling_price'] >831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Won') & (copin['item type'] == 'SLAWR')& (copin['selling_price'] <831), 'item type'] = 'PL'

# %%
# copin.loc[(copin['status']=='Wonderful') & (copin['item type'] == 'SLAWR')& (copin['selling_price'] >831), 'item type'] = 'S'
# copin.loc[(copin['status']=='Wonderful') & (copin['item type'] == 'SLAWR')& (copin['selling_price'] <831), 'item type'] = 'PL'

# %%
(copin['item type'].unique())
# Out:
# array(['S', 'PL'], dtype=object)

# %%
copin=copin.loc[~copin['status'].str.contains('Draft')]

# %%
copin.groupby(['status','item type',]).selling_price.mean()
# Out:
# status           item type
# Lost             PL             984.533805
#                  S              772.982312
# Not lost for AM  PL           27520.911181
#                  S              883.072550
# Offerable        PL             788.000000
#                  S              969.111111
# Offered          S             1017.358491
# Revised          PL             695.217326
#                  S              901.500583
# To be approved   PL             723.747613
#                  S            31426.860557
# Won              PL             686.046100
#                  S              920.138079
# Wonderful        S             1136.000000
# Name: selling_price, dtype: float64

# %%
# copin.loc[(copin['status']=='Not lost for AM') & (copin['item type'] == 'PL')& (copin['selling_price']>920), 'status'] = 'Won'
# copin.loc[(copin['status']=='Not lost for AM') & (copin['item type'] == 'PL')& (copin['selling_price']<920), 'status'] = 'Lost'
# copin.loc[(copin['status']=='Not lost for AM') & (copin['item type'] == 'PL')& (copin['selling_price']==920), 'status'] = 'Won'

# copin.loc[(copin['status']=='Not lost for AM') & (copin['item type'] == 'S')& (copin['selling_price']>920), 'status'] = 'Won'
# copin.loc[(copin['status']=='Not lost for AM') & (copin['item type'] == 'S')& (copin['selling_price']<920), 'status'] = 'Lost'
# copin.loc[(copin['status']=='Not lost for AM') & (copin['item type'] == 'S')& (copin['selling_price']==920), 'status'] = 'Won'

# %%
# copin.loc[(copin['status']=='Offerable') & (copin['item type'] == 'PL')& (copin['selling_price']>920), 'status'] = 'Won'
# copin.loc[(copin['status']=='Offerable') & (copin['item type'] == 'PL')& (copin['selling_price']<920), 'status'] = 'Lost'

# copin.loc[(copin['status']=='Offerable') & (copin['item type'] == 'S')& (copin['selling_price']>920), 'status'] = 'Won'
# copin.loc[(copin['status']=='Offerable') & (copin['item type'] == 'S')& (copin['selling_price']<920), 'status'] = 'Lost'

# %%
# copin.loc[(copin['status']=='Revised') & (copin['item type'] == 'PL')& (copin['selling_price']>920), 'status'] = 'Won'
# copin.loc[(copin['status']=='Revised') & (copin['item type'] == 'PL')& (copin['selling_price']<920), 'status'] = 'Lost'
# copin.loc[(copin['status']=='Revised') & (copin['item type'] == 'PL')& (copin['selling_price']==920), 'status'] = 'Won'

# copin.loc[(copin['status']=='Revised') & (copin['item type'] == 'S')& (copin['selling_price']>920), 'status'] = 'Won'
# copin.loc[(copin['status']=='Revised') & (copin['item type'] == 'S')& (copin['selling_price']<920), 'status'] = 'Lost'
# copin.loc[(copin['status']=='Revised') & (copin['item type'] == 'S')& (copin['selling_price']==920), 'status'] = 'Won'

# %%
copin.loc[(copin['status']=='To be approved') & (copin['item type'] == 'PL')& (copin['selling_price']>920), 'status'] = 'Won'
copin.loc[(copin['status']=='To be approved') & (copin['item type'] == 'PL')& (copin['selling_price']<920), 'status'] = 'Lost'

copin.loc[(copin['status']=='To be approved') & (copin['item type'] == 'S')& (copin['selling_price']>920), 'status'] = 'Won'
copin.loc[(copin['status']=='To be approved') & (copin['item type'] == 'S')& (copin['selling_price']<920), 'status'] = 'Lost'

copin.loc[(copin['status']=='To be approved') & (copin['item type'] == 'S')& (copin['selling_price']==920), 'status'] = 'Won'

# %%
copin.loc[(copin['status']=='Offered') & (copin['item type'] == 'S')& (copin['selling_price']>920), 'status'] = 'Won'
copin.loc[(copin['status']=='Offered') & (copin['item type'] == 'S')& (copin['selling_price']<920), 'status'] = 'Lost'

copin.loc[(copin['status']=='Wonderful') & (copin['item type'] == 'S')& (copin['selling_price']>920), 'status'] = 'Won'
copin.loc[(copin['status']=='Wonderful') & (copin['item type'] == 'S')& (copin['selling_price']<920), 'status'] = 'Lost'

# %%
(copin['status'].unique())
# Out:
# array(['Won', 'Lost'], dtype=object)

# %%
copin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 178524 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             178524 non-null  object
#  1   item_date      178524 non-null  float64
#  2   quantity tons  178524 non-null  object
#  3   customer       178524 non-null  float64
#  4   country        178515 non-null  float64
#  5   status         178524 non-null  object
#  6   item type      178524 non-null  object
#  7   application    178519 non-null  float64
#  8   thickness      178524 non-null  float64
#  9   width          178524 non-null  float64
#  10  material_ref   102043 non-null  object
#  11  product_ref    178524 non-null  int64
#  12  delivery date  178524 non-null  float64
#  13  selling_price  178524 non-null  float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 20.4+ MB

# %%
# copin.dropna(subset='country', inplace=True)
# copin.dropna(subset='application', inplace=True)

# %%
copin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 178515 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             178515 non-null  object
#  1   item_date      178515 non-null  float64
#  2   quantity tons  178515 non-null  object
#  3   customer       178515 non-null  float64
#  4   country        178515 non-null  float64
#  5   status         178515 non-null  object
#  6   item type      178515 non-null  object
#  7   application    178515 non-null  float64
#  8   thickness      178515 non-null  float64
#  9   width          178515 non-null  float64
#  10  material_ref   102042 non-null  object
#  11  product_ref    178515 non-null  int64
#  12  delivery date  178515 non-null  float64
#  13  selling_price  178515 non-null  float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 20.4+ MB

# %%
copin.to_csv("datacleaning_1.csv")

# %%
from google.colab import files
files.download('datacleaning_1.csv')

# %%
url = 'https://raw.githubusercontent.com/PoornimasreJegannathan/ML_Project/main/datacleaning_1.csv'
copin1 = pd.read_csv(url)
copin1.head()
# Out:
# <ipython-input-187-d4c3ba98429d>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   copin1 = pd.read_csv(url)
#    Unnamed: 0                                    id   item_date quantity tons  \
# 0           0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139
# 1           1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839
# 2           2  E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949
# 3           3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065
# 4           4  4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262
#
#      customer  country status item type  application  thickness   width  \
# 0  30156308.0     28.0    Won         S         10.0       2.00  1500.0
# 1  30202938.0     25.0    Won         S         41.0       0.80  1210.0
# 2  30153963.0     30.0    Won        PL         28.0       0.38   952.0
# ...

# %%
copin1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178515 entries, 0 to 178514
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     178515 non-null  int64
#  1   id             178515 non-null  object
#  2   item_date      178515 non-null  float64
#  3   quantity tons  178515 non-null  object
#  4   customer       178515 non-null  float64
#  5   country        178515 non-null  float64
#  6   status         178515 non-null  object
#  7   item type      178515 non-null  object
#  8   application    178515 non-null  float64
#  9   thickness      178515 non-null  float64
#  10  width          178515 non-null  float64
#  11  material_ref   102042 non-null  object
#  12  product_ref    178515 non-null  int64
#  13  delivery date  178515 non-null  float64
#  14  selling_price  178515 non-null  float64
# dtypes: float64(8), int64(2), object(5)
# memory usage: 20.4+ MB

# %%
copin1=copin1.drop(['Unnamed: 0'],axis=1)

# %%
copin1= copin1.rename(columns={'quantity tons':'quantity_tons','item type':'item_type','delivery date':'delivery_date'})

# %%
copin1['item_date']=pd.to_datetime(copin1['item_date'].astype(int).astype(str), format='%Y%m%d',errors='coerce')

# %%
copin1['delivery_date']=pd.to_datetime(copin1['delivery_date'].astype(int).astype(str), format='%Y%m%d',errors='coerce')

# %%
copin1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178515 entries, 0 to 178514
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             178515 non-null  object
#  1   item_date      178513 non-null  datetime64[ns]
#  2   quantity_tons  178515 non-null  object
#  3   customer       178515 non-null  float64
#  4   country        178515 non-null  float64
#  5   status         178515 non-null  object
#  6   item_type      178515 non-null  object
#  7   application    178515 non-null  float64
#  8   thickness      178515 non-null  float64
#  9   width          178515 non-null  float64
#  10  material_ref   102042 non-null  object
#  11  product_ref    178515 non-null  int64
#  12  delivery_date  178513 non-null  datetime64[ns]
#  13  selling_price  178515 non-null  float64
# dtypes: datetime64[ns](2), float64(6), int64(1), object(5)
# memory usage: 19.1+ MB

# %%
##copin1['quantity_tons'] = copin1['quantity_tons'].astype(float)   got error

# %%
copin1['quantity_tons'] = pd.to_numeric( copin1['quantity_tons'], errors='coerce')

# %%
copin1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178515 entries, 0 to 178514
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             178515 non-null  object
#  1   item_date      178513 non-null  datetime64[ns]
#  2   quantity_tons  178514 non-null  float64
#  3   customer       178515 non-null  float64
#  4   country        178515 non-null  float64
#  5   status         178515 non-null  object
#  6   item_type      178515 non-null  object
#  7   application    178515 non-null  float64
#  8   thickness      178515 non-null  float64
#  9   width          178515 non-null  float64
#  10  material_ref   102042 non-null  object
#  11  product_ref    178515 non-null  int64
#  12  delivery_date  178513 non-null  datetime64[ns]
#  13  selling_price  178515 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int64(1), object(4)
# memory usage: 19.1+ MB

# %%
copin1.dropna(subset='item_date', inplace=True)

# %%
copin1.dropna(subset='delivery_date', inplace=True)

# %%
copin1.dropna(subset='quantity_tons', inplace=True)

# %%
# copin1.dropna(subset='material_ref', inplace=True)

# %%
copin1['material_ref']=copin1['material_ref'].astype(str)

# %%
copin1=copin1[~copin1['material_ref'].str.startswith('000000')]

# %%
copin1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155953 entries, 0 to 178498
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             155953 non-null  object
#  1   item_date      155953 non-null  datetime64[ns]
#  2   quantity_tons  155953 non-null  float64
#  3   customer       155953 non-null  float64
#  4   country        155953 non-null  float64
#  5   status         155953 non-null  object
#  6   item_type      155953 non-null  object
#  7   application    155953 non-null  float64
#  8   thickness      155953 non-null  float64
#  9   width          155953 non-null  float64
#  10  material_ref   155953 non-null  object
#  11  product_ref    155953 non-null  int64
#  12  delivery_date  155953 non-null  datetime64[ns]
#  13  selling_price  155953 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int64(1), object(4)
# memory usage: 17.8+ MB

# %%
copin1.head()
# Out:
#                                       id  item_date  quantity_tons  \
# 0   EC06F063-9DF0-440C-8764-0B0C05A4F6AE 2021-04-01      54.151139
# 2   E140FF1B-2407-4C02-A0DD-780A093B1158 2021-04-01     386.127949
# 3   F8D507A0-9C62-4EFE-831E-33E1DA53BB50 2021-04-01     202.411065
# 4   4E1C4E78-152B-430A-8094-ADD889C9D0AD 2021-04-01     785.526262
# 10  EE7EE006-15B3-47A5-A48D-70D54C6B734C 2021-04-01      27.512545
#
#       customer  country status item_type  application  thickness   width  \
# 0   30156308.0     28.0    Won         S         10.0       2.00  1500.0
# 2   30153963.0     30.0    Won        PL         28.0       0.38   952.0
# 3   30349574.0     32.0    Won         S         59.0       2.30  1317.0
# 4   30211560.0     28.0    Won        PL         10.0       4.00  2000.0
# 10  30165529.0     78.0    Won         S         10.0       0.75  1250.0
#
#                material_ref  product_ref delivery_date  selling_price
# ...

# %%
copin1['date_diff'] = (pd.to_datetime(copin1['delivery_date']) - (pd.to_datetime(copin1['item_date']))).dt.days.abs()

# %%
copin1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155953 entries, 0 to 178498
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             155953 non-null  object
#  1   item_date      155953 non-null  datetime64[ns]
#  2   quantity_tons  155953 non-null  float64
#  3   customer       155953 non-null  float64
#  4   country        155953 non-null  float64
#  5   status         155953 non-null  object
#  6   item_type      155953 non-null  object
#  7   application    155953 non-null  float64
#  8   thickness      155953 non-null  float64
#  9   width          155953 non-null  float64
#  10  material_ref   155953 non-null  object
#  11  product_ref    155953 non-null  int64
#  12  delivery_date  155953 non-null  datetime64[ns]
#  13  selling_price  155953 non-null  float64
#  14  date_diff      155953 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(2), object(4)
# memory usage: 19.0+ MB

# %%
len(copin1['date_diff'].unique())
# Out:
# 220

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
cols = ['item_type','application','material_ref']
copin1[cols] = copin1[cols].apply(le.fit_transform)

# %%
copin1[cols].groupby(['item_type','application',]).material_ref.mean()
# Out:
# item_type  application
# 0          0              11425.000000
#            1               4232.760000
#            2               9399.428571
#            3               2295.803922
#            4               7612.723921
#            5               9975.262106
#            7               7152.435185
#            8               9304.987069
#            9               4852.071970
#            10              6516.192478
#            11              6358.608040
#            12              4688.409163
#            13              9878.823420
#            14              7249.786517
#            15             11425.000000
#            16              8852.363136
#            17              8814.945494
#            18              7315.433902
#            19             10947.002144
#            20             11220.522876
#            21              6716.304348
#            23              7950.602804
#            24              7986.122449
# ...

# %%
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='0'), 'material_ref'] = '11425'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='1'), 'material_ref'] = '4233'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='2'), 'material_ref'] = '9399'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='3'), 'material_ref'] = '2295'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='4'), 'material_ref'] = '7612'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='5'), 'material_ref'] = '9975'
# # copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='6'), 'material_ref'] = '11425'

copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='7'), 'material_ref'] = '7152'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='8'), 'material_ref'] = '9304'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='9'), 'material_ref'] = '4852'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='10'), 'material_ref'] = '6516'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='11'), 'material_ref'] = '6358'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='12'), 'material_ref'] = '4688'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='13'), 'material_ref'] = '9878'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='14'), 'material_ref'] = '7249'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='15'), 'material_ref'] = '11425'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='16'), 'material_ref'] = '8852'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='17'), 'material_ref'] = '8814'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='18'), 'material_ref'] = '7315'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='19'), 'material_ref'] = '10947'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='20'), 'material_ref'] = '11220'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='21'), 'material_ref'] = '6716'
# # copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='22'), 'material_ref'] = '11425'

copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='23'), 'material_ref'] = '7950'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='24'), 'material_ref'] = '7986'

# # copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='25'), 'material_ref'] = '11425'

copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='26'), 'material_ref'] = '8811'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='27'), 'material_ref'] = '4247'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '0')& (copin1['application']=='28'), 'material_ref'] = '11358'

# %%
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='0'), 'material_ref'] = '11198'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='1'), 'material_ref'] = '9142'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='2'), 'material_ref'] = '7441'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='3'), 'material_ref'] = '9902'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='4'), 'material_ref'] = '8500'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='5'), 'material_ref'] = '10456'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='6'), 'material_ref'] = '10161'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='7'), 'material_ref'] = '7071'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='8'), 'material_ref'] = '10218'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='9'), 'material_ref'] = '6587'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='10'), 'material_ref'] = '8337'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='11'), 'material_ref'] = '8597'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='12'), 'material_ref'] = '5862'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='13'), 'material_ref'] = '10373'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='14'), 'material_ref'] = '10361'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='15'), 'material_ref'] = '6259'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='16'), 'material_ref'] = '9314'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='17'), 'material_ref'] = '8636'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='18'), 'material_ref'] = '8064'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='19'), 'material_ref'] = '9119'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='20'), 'material_ref'] = '11405'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='21'), 'material_ref'] = '9229'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='22'), 'material_ref'] = '9049'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='23'), 'material_ref'] = '5517'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='24'), 'material_ref'] = '8963'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='25'), 'material_ref'] = '3484'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='26'), 'material_ref'] = '10403'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='27'), 'material_ref'] = '7880'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='28'), 'material_ref'] = '11145'
copin1.loc[(copin1['material_ref']=='nan') & (copin1['item_type'] == '1')& (copin1['application']=='29'), 'material_ref'] = '11425'

# %%
copin1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155953 entries, 0 to 178498
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             155953 non-null  object
#  1   item_date      155953 non-null  datetime64[ns]
#  2   quantity_tons  155953 non-null  float64
#  3   customer       155953 non-null  float64
#  4   country        155953 non-null  float64
#  5   status         155953 non-null  object
#  6   item_type      155953 non-null  int64
#  7   application    155953 non-null  int64
#  8   thickness      155953 non-null  float64
#  9   width          155953 non-null  float64
#  10  material_ref   155953 non-null  object
#  11  product_ref    155953 non-null  int64
#  12  delivery_date  155953 non-null  datetime64[ns]
#  13  selling_price  155953 non-null  float64
#  14  date_diff      155953 non-null  int64
# dtypes: datetime64[ns](2), float64(6), int64(4), object(3)
# memory usage: 19.0+ MB

# %%
copin1['material_ref'].isnull().sum()
# Out:
# 0

# %%
copin1['matref_wd_th'] = copin1['material_ref'].astype(str) +"_"+ copin1['width'].astype(str) +"_"+copin1['thickness'].astype(str)

# %%
copin1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155953 entries, 0 to 178498
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             155953 non-null  object
#  1   item_date      155953 non-null  datetime64[ns]
#  2   quantity_tons  155953 non-null  float64
#  3   customer       155953 non-null  float64
#  4   country        155953 non-null  float64
#  5   status         155953 non-null  object
#  6   item_type      155953 non-null  int64
#  7   application    155953 non-null  int64
#  8   thickness      155953 non-null  float64
#  9   width          155953 non-null  float64
#  10  material_ref   155953 non-null  object
#  11  product_ref    155953 non-null  int64
#  12  delivery_date  155953 non-null  datetime64[ns]
#  13  selling_price  155953 non-null  float64
#  14  date_diff      155953 non-null  int64
#  15  matref_wd_th   155953 non-null  object
# ...

# %%
copin1.head()
# Out:
#                                       id  item_date  quantity_tons  \
# 0   EC06F063-9DF0-440C-8764-0B0C05A4F6AE 2021-04-01      54.151139
# 2   E140FF1B-2407-4C02-A0DD-780A093B1158 2021-04-01     386.127949
# 3   F8D507A0-9C62-4EFE-831E-33E1DA53BB50 2021-04-01     202.411065
# 4   4E1C4E78-152B-430A-8094-ADD889C9D0AD 2021-04-01     785.526262
# 10  EE7EE006-15B3-47A5-A48D-70D54C6B734C 2021-04-01      27.512545
#
#       customer  country status  item_type  application  thickness   width  \
# 0   30156308.0     28.0    Won          1            4       2.00  1500.0
# 2   30153963.0     30.0    Won          0           12       0.38   952.0
# 3   30349574.0     32.0    Won          1           21       2.30  1317.0
# 4   30211560.0     28.0    Won          0            4       4.00  2000.0
# 10  30165529.0     78.0    Won          1            4       0.75  1250.0
#
#    material_ref  product_ref delivery_date  selling_price  date_diff  \
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
cols = ['status','application','customer','country']
copin1[cols] = copin1[cols].apply(le.fit_transform)

# %%
cols2=['status','application','customer','country','date_diff','selling_price']
sns.heatmap(copin1[cols2].corr(),annot=True)
plt.show()

# %%
copin1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155953 entries, 0 to 178498
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             155953 non-null  object
#  1   item_date      155953 non-null  datetime64[ns]
#  2   quantity_tons  155953 non-null  float64
#  3   customer       155953 non-null  int64
#  4   country        155953 non-null  int64
#  5   status         155953 non-null  int64
#  6   item_type      155953 non-null  int64
#  7   application    155953 non-null  int64
#  8   thickness      155953 non-null  float64
#  9   width          155953 non-null  float64
#  10  material_ref   155953 non-null  object
#  11  product_ref    155953 non-null  int64
#  12  delivery_date  155953 non-null  datetime64[ns]
#  13  selling_price  155953 non-null  float64
#  14  date_diff      155953 non-null  int64
#  15  matref_wd_th   155953 non-null  object
# ...
